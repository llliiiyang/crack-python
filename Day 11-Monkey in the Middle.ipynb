# %% [markdown]
# # --Part 1--

# %%
import operator
ops = {
    "+": operator.add,
    "-": operator.sub,
    "*": operator.mul,
    "//": operator.floordiv,
    "**": operator.pow
} 

class Monkey:
    def __init__(self, name, items, operator,op_value, test, target):
        self.name=name
        self.items=items
        self.operator=operator
        self.test=test
        self.target=target
        
    def operate_test(self,items):
        op_func = ops[operator]
        i=0
        for item in items:
            new_item=item // 3
            new_item=op_func(new_item,op_value)
            #new_item=new_item // test
            items[i]=new_item
            i+=1  
        return self.items
        
    def get_item(self, items_got):
        self.items=self.items.extend(items_got)
    
    
    def throw_item(self):
        operate_test(self.items)
        for item in self.items:
            if item // self.test ==0:
                monkeys[self.target[0]].items.append(item)
                self.items.pop(0)
            else:
                monkeys[self.target[1]].items.append(item)
                self.items.pop(0)
            
            
monkeys={}
monkeys[0]=Monkey("0",[89, 95, 92, 64, 87, 68],"*",11,2,(7,4))
monkeys[1]=Monkey("1",[87, 67],"+",1,13,(3,6))
monkeys[2]=Monkey("2",[95, 79, 92, 82, 60],"+",6,3,(1,6))
monkeys[3]=Monkey("3",[67, 97, 56],"**",2,17,(7,0))
monkeys[4]=Monkey("4",[80, 68, 87, 94, 61, 59, 50, 68],"*",7,19,(5,2))
...
# Out:
# Ellipsis

# %% [markdown]
# # Class note

# %%
class Dog:
 
    # A simple class
    # attribute
    attr1 = "mammal"
    attr2 = "dog"
 
    # A sample method
    def fun(self):
        print("I'm a", self.attr1)
        print("I'm a", self.attr2)
 
 
# Driver code
# Object instantiation
Rodger = Dog()
 
# Accessing class attributes
# and method through objects
print(Rodger.attr1)
Rodger.fun()

#When we call a method of this object as myobject.method(arg1, arg2), this is automatically
#converted by Python into MyClass.method(myobject, arg1, arg2) – this is all the special self is about.

class Person:
 
    # init method or constructor
    def __init__(self, name):
        self.name = name
 
    # Sample Method
    def say_hi(self):
        print('Hello, my name is', self.name)
 
 
p = Person('Nikhil')
p.say_hi()
# Out:
# mammal
# I'm a mammal
# I'm a dog

# %%
class Dog:
 
    # Class Variable
    animal = 'dog'
 
    # The init method or constructor
    def __init__(self, breed):
 
        # Instance Variable
        self.breed = breed
 
    # Adds an instance variable
    def setColor(self, color):
        self.color = color
 
    # Retrieves instance variable
    def getColor(self):
        return self.color
 
 
# Driver Code
Rodger = Dog("pug")
Rodger.setColor("brown")
print(Rodger.getColor())

# %%
import operator
ops = {
    "+": operator.add,
    "-": operator.sub,
    "*": operator.mul,
    "//": operator.floordiv
}   
op_char = input('enter a operand')
op_func = ops[op_char]
result = op_func(a, b)
# Out:
# enter a operand *
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 10
#       8 op_char = input('enter a operand')
#       9 op_func = ops[op_char]
# ---> 10 result = op_func(a, b)
#
# NameError: name 'a' is not defined
